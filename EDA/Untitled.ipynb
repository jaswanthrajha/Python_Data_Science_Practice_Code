# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = pd.read_csv('file:///C:/Users/dell/Desktop/StudentsPerformance.csv')
a
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# # 1). List out the set of categorical and numerical variables in the dataset . (1 Mark)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# # 2). Find out the missing values ( in %) for all variables in the data set? (1 Mark)

# %%
pd.options.display.max_rows=None
a.isnull().sum()*100/a.shape[0]
# Out:
# gender                         0.0
# race/ethnicity                 0.0
# parental level of education    0.0
# lunch                          0.0
# test preparation course        0.0
# math score                     0.0
# reading score                  0.0
# writing score                  0.0
# dtype: float64

# %% [markdown]
# # 3). Find the Percentage of students who have completed the test preparation course. (1 Mark)

# %%
a[(a['test preparation course']=='completed')]['test preparation course'].value_counts()*100/a.shape[0]
# Out:
# completed    35.8
# Name: test preparation course, dtype: float64

# %% [markdown]
# # 4). Find the levels of parental education. What is the level of education held by majority of parents. (1 Mark)

# %%
a['parental level of education'].max()
# Out:
# 'some high school'

# %% [markdown]
# # 5). Add a new column to the dataset which is a total score of each student obtained by combining math, reading and writing score. (1 Mark)

# %%
a['combining score']= a['math score']+a['reading score']+a['writing score']
a.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    combining score
# 0              218
# 1              247
# 2              278
# 3              148
# 4              229

# %% [markdown]
# # 6.a). Create dummy columns for the categorical variable 'lunch'. (1 mark)

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
a['lunch lab']= lb.fit_transform(a['lunch'])
a
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# # b) Retain the column lunch_standard and remove the other one. (2 marks)

# %%
b = a[(a.lunch=="standard")]
b
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# 6    female        group B                some college  standard
# 10     male        group C          associate's degree  standard
# 11     male        group D          associate's degree  standard
# 12   female        group B                 high school  standard
# 13     male        group A                some college  standard
# 14   female        group A             master's degree  standard
# 15   female        group C            some high school  standard
# 16     male        group C                 high school  standard
# ...

# %% [markdown]
# # c) Analyze and compare the percentage of female’s vs percentage of males who receive standard lunch. (2 Marks)

# %%
# Out:
# female    51.007752
# male      48.992248
# Name: gender, dtype: float64

# %%
f=a.groupby('gender')

# %%
f.lunch.value_counts()*100/
# Out:
# gender  lunch
# female  standard        32.9
#         free/reduced    18.9
# male    standard        31.6
#         free/reduced    16.6
# Name: lunch, dtype: float64

# %% [markdown]
# # 7.a). Plot a suitable graph for comparing parental level of education vs. the total score of the students? Write your inferences (3 marks)

# %%
a.groupby('parental level of education')['combining score'].median().plot(kind='bar')

# %%
a.shape
# Out:
# (1000, 10)

# %% [markdown]
# # 8.a). Consider the variable 'math score' and check for existence of outliers. If present, then find the list of outliers. How do you treat these outliers (5 Marks)?

# %%
sns.boxplot(a['math score'])

# %%
sns.distplot(a['math score'])

# %%
a['math score'].skew()
# Out:
# -0.27893514909431694

# %%
a['math score'].quantile([.25])(-).quantile([.75])
# Out:
# 0.25    57.0
# 0.75    77.0
# Name: math score, dtype: float64

# %%
q3=a['math score'].quantile(.75)
q1=a['math score'].quantile(.25)
iqr = q3-q1

# %%
q3+(1.5)*iqr
# Out:
# 107.0

# %%
q1-(1.5)*iqr
# Out:
# 27.0

# %% [markdown]
# # b). Find the correlation between reading score and writing score. Visualize the same using a suitable map. And draw your inferences (5 Marks)

# %%
sns.heatmap(a[['reading score','writing score']].corr())

# %% [markdown]
# # c). Which encoding techniques do you recommend to the categorical variables? And apply those encoding techniques to these categorical variables (2 marks)

# %%
a
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
pd.get_dummies(a,columns=['gender'],)
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# 5          group B          associate's degree      standard
# 6          group B                some college      standard
# 7          group B                some college  free/reduced
# 8          group D                 high school  free/reduced
# 9          group B                 high school  free/reduced
# 10         group C          associate's degree      standard
# 11         group D          associate's degree      standard
# 12         group B                 high school      standard
# 13         group A                some college      standard
# ...
